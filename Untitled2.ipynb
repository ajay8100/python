# %%
print("ajay")
# Out:
# ajay

# %%
print("ajay")
# Out:
# ajay

# %%
print("ajay")
# Out:
# ajay

# %% [markdown]
# #variable creation

# %%
x=10

# %%
y=5

# %%
x+y
# Out:
# 15

# %% [markdown]
# #rules for variable

# %%
#etxt

# %%
name = "ajay"
age=20
print("my name is",name,"age is",age)
# Out:
# my name is ajay age is 20

# %%
name = input("enter name")
age=int(input("enter age"))
print("my name is",name,"age is",age)
# Out:
# enter nameajay
# enter age20
# my name is ajay age is 20

# %%
x=int(input("enter value"))
y=int(input("enter value"))
print("x+y is",x+y)
# Out:
# enter value2
# enter value2
# x+y is 4

# %%
x=10
y=5.12
z=5+6j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
c=complex(2,3)
print(c)
# Out:
# (2+3j)

# %%
x = false
y = true
x<y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-30e15ec96438> in <module>()
# ----> 1 x = false
#       2 y = true
#       3 x<y
#
# NameError: name 'false' is not defined

# %%
x=6
y=7
x>y
# Out:
# False

# %%
s1="abc"
s2="xyz"
print(type(s1),type(s2))
# Out:
# <class 'str'> <class 'str'>

# %%
i=24
print(type(i))
# Out:
# <class 'int'>

# %%
i=24
print(type(i))
s1=str(i)
print(type(s1))
f1=float(s1)
print(type(f1))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
a=xyz
print(lengt(a))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-5ddf7fa557ed> in <module>()
# ----> 1 a=xyz
#       2 print(lengt(a))
#
# NameError: name 'xyz' is not defined

# %%
a=str(12345)
print(len(a))
# Out:
# 5

# %%
n1=120,200,300
a=b=c=10
m,n,o=1,2,3
print(n1)
print(a,b,c)
print(m,n,o)
# Out:
# (120, 200, 300)
# 10 10 10
# 1 2 3

# %% [markdown]
# #arithmetic operator

# %% [markdown]
# #operators

# %% [markdown]
# ##arithmetic operators

# %% [markdown]
# +,
# -,
# *,
# /,
# %,
# **,
# //,

# %% [markdown]
# # #relational operators

# %% [markdown]
# ==,!=,>,<,<=,>=

# %%
x

# %% [markdown]
# #logical  operators

# %%
i=100
a1=(i>150 and i<100)
print(a1)
# Out:
# False

# %%
i=20
a2=(i<5 and i>10)
print(a2)
# Out:
# False

# %% [markdown]
# #membership operator
# in
# notin

# %%
str1="abc"
print('a' in str1)
print('r' not in str1)
# Out:
# True
# True

# %% [markdown]
# #controlflow statements
# ##1.conditional statements
# ##2.looping statements

# %% [markdown]
# # if else statements

# %%
if()

# %% [markdown]
# ### check whether the given number is even or not

# %%
n=int(input("enter a number"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-8080c32f212c> in <module>()
# ----> 1 n=int(input("enter a number"))
#       2
#       3
#       4
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:

# %% [markdown]
# ## check whether the given  number is perfectly multiple of 3 and 5

# %%
n=int(input("enter the number"))
if n%3==0 and n%5==0:
    print("yes")
else:
  print("no")
# Out:
# enter the number15
# yes

# %% [markdown]
# ##check given number is +ve ,-ve or 0

# %%
n= int(input("enter the number"))
if n=positive,negative,0:
    print("yes")
else:
    print("no")
# Out:
#   File "<ipython-input-57-f3e52cbe33fb>", line 2
#     if n=positive,negative,0:
#         ^
# SyntaxError: invalid syntax
